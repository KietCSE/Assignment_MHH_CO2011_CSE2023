# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Data

# %%
n, m, nS = 8, 5, 2 # number of products, parts, scenarios

# %%
products = ['product ' + str(i + 1) for i in range(n)]
parts = ['part ' + str(j + 1) for j in range(m)]
scenarios = ['scenario ' + str(k + 1) for k in range(nS)]

# %%
density = pd.DataFrame(
    {
        'scenarios' : scenarios,
        'density' : [.5] * nS
    }
).set_index('scenarios')
density
# Out:
#             density
# scenarios
# scenario 1      0.5
# scenario 2      0.5

# %%
np.random.seed(42)

demands = pd.DataFrame(
    {
        'products' : np.repeat(products, nS),
        'scenarios' : scenarios * n,
        'demand' : np.array([np.random.binomial(10, .5, n) for k in range(nS)]).reshape(-1)
    }
).set_index(['products', 'scenarios'])

l = pd.DataFrame(
    {
        'products' : products,
        'additional cost' : np.random.randint(100, 200, n)
    }
).set_index('products') # l_i := additional cost to satify a unit of demand for product i

q = pd.DataFrame(
    {
        'products' : products,
        'selling price' : np.random.randint(200, 300, n)
    }
).set_index('products') # q_i := unit selling price of product i

b = pd.DataFrame(
    {
        'parts' : parts,
        'cost per unit' : np.random.randint(2, 5, m)
    }
).set_index('parts') # b_j := cost per unit of part j

s = pd.DataFrame(
    {
        'parts' : parts,
        'salvage' : np.random.randint(1, 4, m)
    }
).set_index('parts') # s_j := salvage values

for j in range(m):
    if s.iloc[j, 0] >= b.iloc[j, 0]:
        s.iloc[j, 0] = b.iloc[j, 0] - 1

A = pd.DataFrame(
    {
        'products' : np.repeat(products, m),
        'parts' : parts * n,
        'requirements' :  np.random.randint(0, 6, size=(n, m)).reshape(-1)
    }
).set_index(['products', 'parts'])

# %%
demands
# Out:
#                       demand
# products  scenarios
# product 1 scenario 1       4
#           scenario 2       8
# product 2 scenario 1       6
#           scenario 2       5
# product 3 scenario 1       3
#           scenario 2       3
# product 4 scenario 1       3
#           scenario 2       7
# product 5 scenario 1       5
#           scenario 2       6
# product 6 scenario 1       2
#           scenario 2       8
# product 7 scenario 1       7
#           scenario 2       4
# product 8 scenario 1       4
#           scenario 2       4

# %%
l
# Out:
#            additional cost
# products
# product 1              175
# product 2              157
# product 3              121
# product 4              188
# product 5              148
# product 6              190
# product 7              158
# product 8              141

# %%
q
# Out:
#            selling price
# products
# product 1            291
# product 2            259
# product 3            279
# product 4            214
# product 5            261
# product 6            261
# product 7            246
# product 8            261

# %%
b
# Out:
#         cost per unit
# parts
# part 1              4
# part 2              4
# part 3              2
# part 4              4
# part 5              2

# %%
s
# Out:
#         salvage
# parts
# part 1        3
# part 2        3
# part 3        1
# part 4        1
# part 5        1

# %%
A
# Out:
#                   requirements
# products  parts
# product 1 part 1             1
#           part 2             3
#           part 3             0
#           part 4             3
#           part 5             5
# product 2 part 1             1
#           part 2             1
#           part 3             0
#           part 4             1
#           part 5             4
# product 3 part 1             1
#           part 2             3
#           part 3             3
#           part 4             3
#           part 5             3
# product 4 part 1             4
#           part 2             2
#           part 3             5
#           part 4             0
#           part 5             3
# product 5 part 1             1
#           part 2             3
#           part 3             1
#           part 4             5
#           part 5             5
# product 6 part 1             5
#           part 2             1
#           part 3             3
#           part 4             5
#           part 5             4
# product 7 part 1             1
#           part 2             1
#           part 3             3
#           part 4             1
#           part 5             1
# product 8 part 1             5
#           part 2             3
#           part 3             5
#           part 4             5
#           part 5             3

# %%
pd.pivot_table(A.reset_index(), columns=['parts'], index=['products'])
# Out:
#           requirements
# parts           part 1 part 2 part 3 part 4 part 5
# products
# product 1            1      3      0      3      5
# product 2            1      1      0      1      4
# product 3            1      3      3      3      3
# product 4            4      2      5      0      3
# product 5            1      3      1      5      5
# product 6            5      1      3      5      4
# product 7            1      1      3      1      1
# product 8            5      3      5      5      3

# %% [markdown]
# ## Symbol declaration

# %%
from gamspy import Container, Set, Parameter, Variable, Equation, Model, Sum, Sense

# %% [markdown]
# ### Container

# %%
model = Container()

# %% [markdown]
# ### Sets

# %%
i = Set(container=model, name='i', description='products', records=products)
j = Set(container=model, name='j', description='parts', records=parts)
k = Set(container=model, name='k', description='scenarios', records=scenarios)

# %% [markdown]
# ### Parameters

# %%
A = Parameter(container=model, name='A', domain=[i, j], description='Requirements', records=A.reset_index())
A.records
# Out:
#      products   parts  value
# 0   product 1  part 1    1.0
# 1   product 1  part 2    3.0
# 2   product 1  part 3    0.0
# 3   product 1  part 4    3.0
# 4   product 1  part 5    5.0
# 5   product 2  part 1    1.0
# 6   product 2  part 2    1.0
# 7   product 2  part 3    0.0
# 8   product 2  part 4    1.0
# 9   product 2  part 5    4.0
# 10  product 3  part 1    1.0
# 11  product 3  part 2    3.0
# 12  product 3  part 3    3.0
# 13  product 3  part 4    3.0
# 14  product 3  part 5    3.0
# 15  product 4  part 1    4.0
# 16  product 4  part 2    2.0
# 17  product 4  part 3    5.0
# 18  product 4  part 4    0.0
# 19  product 4  part 5    3.0
# 20  product 5  part 1    1.0
# 21  product 5  part 2    3.0
# 22  product 5  part 3    1.0
# 23  product 5  part 4    5.0
# 24  product 5  part 5    5.0
# 25  product 6  part 1    5.0
# 26  product 6  part 2    1.0
# 27  product 6  part 3    3.0
# 28  product 6  part 4    5.0
# 29  product 6  part 5    4.0
# 30  product 7  part 1    1.0
# 31  product 7  part 2    1.0
# 32  product 7  part 3    3.0
# 33  product 7  part 4    1.0
# 34  product 7  part 5    1.0
# 35  product 8  part 1    5.0
# 36  product 8  part 2    3.0
# 37  product 8  part 3    5.0
# 38  product 8  part 4    5.0
# 39  product 8  part 5    3.0

# %%
pd.pivot_table(A.records, columns=['parts'], index=['products'])
# Out:
#            value
# parts     part 1 part 2 part 3 part 4 part 5
# products
# product 1    1.0    3.0    0.0    3.0    5.0
# product 2    1.0    1.0    0.0    1.0    4.0
# product 3    1.0    3.0    3.0    3.0    3.0
# product 4    4.0    2.0    5.0    0.0    3.0
# product 5    1.0    3.0    1.0    5.0    5.0
# product 6    5.0    1.0    3.0    5.0    4.0
# product 7    1.0    1.0    3.0    1.0    1.0
# product 8    5.0    3.0    5.0    5.0    3.0

# %%
l = Parameter(container=model, name='l', domain=[i],
              description='l_i := additional cost to satify a unit of demand for product i', records=l.reset_index())
l.records
# Out:
#     products  value
# 0  product 1  175.0
# 1  product 2  157.0
# 2  product 3  121.0
# 3  product 4  188.0
# 4  product 5  148.0
# 5  product 6  190.0
# 6  product 7  158.0
# 7  product 8  141.0

# %%
q = Parameter(container=model, name='q', domain=[i],
              description='q_i := unit selling price of product i', records=q.reset_index())
q.records
# Out:
#     products  value
# 0  product 1  291.0
# 1  product 2  259.0
# 2  product 3  279.0
# 3  product 4  214.0
# 4  product 5  261.0
# 5  product 6  261.0
# 6  product 7  246.0
# 7  product 8  261.0

# %%
b = Parameter(container=model, name='b', domain=[j],
              description='b_j := cost per unit of part j', records=b.reset_index())
b.records
# Out:
#     parts  value
# 0  part 1    4.0
# 1  part 2    4.0
# 2  part 3    2.0
# 3  part 4    4.0
# 4  part 5    2.0

# %%
s = Parameter(container=model, name='s', domain=[j],
              description='s_j := salvage values', records=s.reset_index())
s.records
# Out:
#     parts  value
# 0  part 1    3.0
# 1  part 2    3.0
# 2  part 3    1.0
# 3  part 4    1.0
# 4  part 5    1.0

# %%
d = Parameter(container=model, name='d', domain=[i, k], description='Demands', records=demands.reset_index())
d.records
# Out:
#      products   scenarios  value
# 0   product 1  scenario 1    4.0
# 1   product 1  scenario 2    8.0
# 2   product 2  scenario 1    6.0
# 3   product 2  scenario 2    5.0
# 4   product 3  scenario 1    3.0
# 5   product 3  scenario 2    3.0
# 6   product 4  scenario 1    3.0
# 7   product 4  scenario 2    7.0
# 8   product 5  scenario 1    5.0
# 9   product 5  scenario 2    6.0
# 10  product 6  scenario 1    2.0
# 11  product 6  scenario 2    8.0
# 12  product 7  scenario 1    7.0
# 13  product 7  scenario 2    4.0
# 14  product 8  scenario 1    4.0
# 15  product 8  scenario 2    4.0

# %%
p = Parameter(container=model, name='p', domain=[k], description='Density', records=density.reset_index())
p.records
# Out:
#     scenarios  value
# 0  scenario 1    0.5
# 1  scenario 2    0.5

# %% [markdown]
# ### Variables

# %%
x = Variable(container=model, name='x', type='INTEGER', domain=[j], description='x_j := parts to be ordered (1st stage decision)')

# %%
y = Variable(container=model, name='y', type='INTEGER', domain=[j, k], description='y_j := Parts left in inventory')

# %%
z = Variable(container=model, name='z', type='INTEGER', domain=[i, k], description='z_i := number unit of part j produced')

# %% [markdown]
# ### Equation

# %%
eq1 = Equation(container=model, name='eq1', domain=[j, k])
eq1[j, k] = y[j, k] == x[j] - Sum(domain=[i], expression=A[i, j] * z[i, k])

# %%
eq2 = Equation(container=model, name='eq2', domain=[j])
eq2[j] = x[j] >= 0

# %%
eq3 = Equation(container=model, name='eq3', domain=[j, k])
eq3[j, k] = y[j, k] >= 0

# %%
eq4 = Equation(container=model, name='eq4', domain=[i, k])
eq4[i, k] = z[i, k] >= 0

# %%
eq5 = Equation(container=model, name='eq5', domain=[i, k])
eq5[i, k] = z[i, k] <= d[i, k]

# %%
print(type(i))
# Out:
# <class 'gamspy._symbols.set.Set'>

# %% [markdown]
# ### Objective function

# %%
Z = Sum(domain=[i], expression=(l[i] - q[i]) * z[i, k]) - Sum(domain=[j], expression=s[j] * y[j, k])
obj = Sum(domain=[j], expression=b[j] * x[j]) + Sum(domain=[k], \
    expression=(Z * p[k]))

# %%
model.getEquations()
# Out:
# [<Eq Equation `eq1` (0x1a89d1a6d10)>,
#  <Geq Equation `eq2` (0x1a89d1a6b90)>,
#  <Geq Equation `eq3` (0x1a89d136080)>,
#  <Geq Equation `eq4` (0x1a89d1361d0)>,
#  <Leq Equation `eq5` (0x1a89d134eb0)>]

# %%
# obj = Sum(domain=[j], expression=b[j] * x[j]) + Sum(domain=[k], \
#     expression=(Sum(domain=[i], expression=(l[i] - q[i]) * z[i, k]) + \
#                 Sum(domain=[j], expression=s[j] * y[j, k])) * p[k])

# %% [markdown]
# ### Model

# %%
problem1 = Model(container=model, name='Problem_1', problem='MIP', sense=Sense.MIN, equations=model.getEquations(), objective=obj)

# %% [markdown]
# ### Solve

# %%
import sys
problem1.solve(output=sys.stdout)
# Out:
# --- Job _gams_py_gjo0.gms Start 11/30/23 20:00:39 45.2.0 e4d2ee31 WEX-WEI x86 64bit/MS Windows
# --- Applying:
#     C:\Users\mayvp\AppData\Local\Programs\Python\Python310\Lib\site-packages\gamspy_base\gmsprmNT.txt
# --- GAMS Parameters defined
#     LP CPLEX
#     MIP CPLEX
#     RMIP CPLEX
#     NLP CONOPT
#     MCP PATH
#     MPEC NLPEC
#     RMPEC CONVERT
#     CNS CONOPT
#     DNLP CONOPT
#     RMINLP CONOPT
#     MINLP SBB
#     QCP CONOPT
#     MIQCP SBB
#     RMIQCP CONOPT
#     EMP CONVERT
#     Input C:\Users\mayvp\AppData\Local\Temp\tmpo1gzjwe0\_gams_py_gjo0.gms
#     Output C:\Users\mayvp\AppData\Local\Temp\tmpo1gzjwe0\_gams_py_gjo0.lst
#     Save C:\Users\mayvp\AppData\Local\Temp\tmpo1gzjwe0\_gams_py_gcp0.g00
#     ScrDir C:\Users\mayvp\AppData\Local\Temp\tmpo1gzjwe0\225a\
#     SysDir C:\Users\mayvp\AppData\Local\Programs\Python\Python310\Lib\site-packages\gamspy_base\
#     CurDir C:\Users\mayvp\AppData\Local\Temp\tmpo1gzjwe0\
#     LogOption 3
#     LogFile C:\Users\mayvp\AppData\Local\Temp\tmpo1gzjwe0\_gams_py_gjo0.log
#     GDX C:\Users\mayvp\AppData\Local\Temp\tmpo1gzjwe0\_gams_py_gcp1.gdx
# Licensee: GAMS Demo, for EULA and demo limitations see   G230930/0001CB-GEN
#           https://www.gams.com/latest/docs/UG%5FLicense.html         DC0000
#           C:\Users\mayvp\AppData\Local\Programs\Python\Python310\Lib\site-packages\gamspy_base\gamslice.txt
#           Demo license for demonstration and instructional purposes only
# Processor information: 1 socket(s), 4 core(s), and 8 thread(s) available
# GAMS 45.2.0   Copyright (C) 1987-2023 GAMS Development. All rights reserved
# --- Starting compilation
# --- _gams_py_gjo0.gms(2) 2 Mb
# --- GDXin=C:\Users\mayvp\AppData\Local\Temp\tmpo1gzjwe0\_gams_py_gcp0.gdx
# --- GDX File ($gdxIn) C:\Users\mayvp\AppData\Local\Temp\tmpo1gzjwe0\_gams_py_gcp0.gdx
# --- _gams_py_gjo0.gms(157) 3 Mb
# --- Starting execution: elapsed 0:00:00.066
# --- Generating MIP model Problem_1
# --- _gams_py_gjo0.gms(106) 4 Mb
# ---   58 rows  32 columns  173 non-zeroes
# ---   31 discrete-columns
# --- Range statistics (absolute non-zero finite values)
# --- RHS       [min, max] : [ 2.000E+00, 8.000E+00] - Zero values observed as well
# --- Bound     [min, max] : [        NA,        NA] - Zero values observed as well
# --- Matrix    [min, max] : [ 5.000E-01, 7.900E+01]
# --- Executing CPLEX (Solvelink=2): elapsed 0:00:00.098
#
# IBM ILOG CPLEX   45.2.0 e4d2ee31 Oct 30, 2023          WEI x86 64bit/MS Window
#
# *** This solver runs with a demo license. No commercial use.
# --- GMO setup time: 0.00s
# --- GMO memory 0.51 Mb (peak 0.51 Mb)
# --- Dictionary memory 0.00 Mb
# --- Cplex 22.1.1.0 link memory 0.00 Mb (peak 0.01 Mb)
# --- Starting Cplex
#
# Version identifier: 22.1.1.0 | 2022-11-27 | 9160aff4d
# CPXPARAM_Advance                                 0
# CPXPARAM_Threads                                 1
# CPXPARAM_MIP_Display                             4
# CPXPARAM_MIP_Pool_Capacity                       0
# CPXPARAM_MIP_Tolerances_AbsMIPGap                0
# Generic callback                                 0x50
# Found incumbent of value 0.000000 after 0.00 sec. (0.00 ticks)
# Tried aggregator 2 times.
# MIP Presolve eliminated 47 rows and 1 columns.
# MIP Presolve added 13 rows and 13 columns.
# Aggregator did 5 substitutions.
# Reduced MIP has 18 rows, 39 columns, and 123 nonzeros.
# Reduced MIP has 0 binaries, 39 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.00 sec. (0.08 ticks)
# Tried aggregator 1 time.
# Detecting symmetries...
# MIP Presolve eliminated 13 rows and 13 columns.
# MIP Presolve added 13 rows and 13 columns.
# Reduced MIP has 18 rows, 39 columns, and 123 nonzeros.
# Reduced MIP has 0 binaries, 39 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.00 sec. (0.06 ticks)
# MIP emphasis: balance optimality and feasibility.
# MIP search method: dynamic search.
# Parallel mode: none, using 1 thread.
# Tried aggregator 1 time.
# LP Presolve eliminated 16 rows and 33 columns.
# Reduced LP has 2 rows, 6 columns, and 8 nonzeros.
# Presolve time = 0.00 sec. (0.02 ticks)
#
# Iteration log . . .
# Iteration:     1   Dual infeasibility =             0.500000
# Iteration:     3   Dual objective     =         -2200.900000
# Initializing dual steep norms . . .
# Root relaxation solution time = 0.00 sec. (0.03 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap
#
# *     0+    0                            0.0000                            ---
# Found incumbent of value 0.000000 after 0.00 sec. (0.21 ticks)
#       0     0    -2200.9000     8        0.0000    -2200.9000        3     ---
# *     0+    0                        -2200.0000    -2200.9000             0.04%
# Found incumbent of value -2200.000000 after 0.00 sec. (0.25 ticks)
# *     0     0      integral     0    -2200.5000    -2200.5000        3    0.00%
# Elapsed time = 0.00 sec. (0.30 ticks, tree = 0.01 MB)
# Found incumbent of value -2200.500000 after 0.00 sec. (0.30 ticks)
#
# Root node processing (before b&c):
#   Real time             =    0.00 sec. (0.30 ticks)
# Sequential b&c:
#   Real time             =    0.00 sec. (0.00 ticks)
#                           ------------
# Total (root+branch&cut) =    0.00 sec. (0.30 ticks)
#
# --- MIP status (101): integer optimal solution.
# --- Cplex Time: 0.00sec (det. 0.30 ticks)
#
# --- Returning a primal only solution to GAMS (marginals all set to NA).
# --- Fixing integer variables and solving final LP...
#
# Version identifier: 22.1.1.0 | 2022-11-27 | 9160aff4d
# CPXPARAM_Advance                                 2
# CPXPARAM_Threads                                 1
# CPXPARAM_MIP_Display                             4
# CPXPARAM_MIP_Pool_Capacity                       0
# CPXPARAM_MIP_Tolerances_AbsMIPGap                0
# Tried aggregator 1 time.
# LP Presolve eliminated 57 rows and 32 columns.
# All rows and columns eliminated.
# Presolve time = 0.00 sec. (0.02 ticks)
#
# --- Fixed MIP status (1): optimal.
# --- Cplex Time: 0.00sec (det. 0.04 ticks)
#
#
# Proven optimal solution
# MIP Solution:        -2200.500000    (3 iterations, 0 nodes)
# Final Solve:         -2200.500000    (0 iterations)
#
# Best possible:       -2200.500000
# Absolute gap:            0.000000
# Relative gap:            0.000000
#
# --- Reading solution for model Problem_1
# --- Executing after solve: elapsed 0:00:00.269
# --- _gams_py_gjo0.gms(136) 4 Mb
# --- GDX File C:\Users\mayvp\AppData\Local\Temp\tmpo1gzjwe0\_gams_py_gcp1.gdx
# *** Status: Normal completion
# --- Job _gams_py_gjo0.gms Stop 11/30/23 20:00:40 elapsed 0:00:00.277

# %%
x.records.set_index('j')
# Out:
#         level  marginal  lower  upper  scale
# j
# part 1   55.0       4.0    0.0    inf    1.0
# part 2   73.0       4.0    0.0    inf    1.0
# part 3   61.0       2.0    0.0    inf    1.0
# part 4   97.0       4.0    0.0    inf    1.0
# part 5  119.0       2.0    0.0    inf    1.0

# %%
y.records.set_index(['j', 'k'])
# Out:
#                    level  marginal  lower  upper  scale
# j      k
# part 1 scenario 1    0.0      -1.5    0.0    inf    1.0
#        scenario 2    4.0      -1.5    0.0    inf    1.0
# part 2 scenario 1   10.0      -1.5    0.0    inf    1.0
#        scenario 2    0.0      -1.5    0.0    inf    1.0
# part 3 scenario 1    0.0      -0.5    0.0    inf    1.0
#        scenario 2   11.0      -0.5    0.0    inf    1.0
# part 4 scenario 1    8.0      -0.5    0.0    inf    1.0
#        scenario 2    0.0      -0.5    0.0    inf    1.0
# part 5 scenario 1   14.0      -0.5    0.0    inf    1.0
#        scenario 2    0.0      -0.5    0.0    inf    1.0

# %%
z.records.set_index(['i', 'k'])
# Out:
#                       level  marginal  lower  upper  scale
# i         k
# product 1 scenario 1    4.0     -58.0    0.0    inf    1.0
#           scenario 2    8.0     -58.0    0.0    inf    1.0
# product 2 scenario 1    6.0     -51.0    0.0    inf    1.0
#           scenario 2    5.0     -51.0    0.0    inf    1.0
# product 3 scenario 1    3.0     -79.0    0.0    inf    1.0
#           scenario 2    3.0     -79.0    0.0    inf    1.0
# product 4 scenario 1    0.0     -13.0    0.0    inf    1.0
#           scenario 2    0.0     -13.0    0.0    inf    1.0
# product 5 scenario 1    5.0     -56.5    0.0    inf    1.0
#           scenario 2    6.0     -56.5    0.0    inf    1.0
# product 6 scenario 1    2.0     -35.5    0.0    inf    1.0
#           scenario 2    1.0     -35.5    0.0    inf    1.0
# product 7 scenario 1    7.0     -44.0    0.0    inf    1.0
#           scenario 2    4.0     -44.0    0.0    inf    1.0
# product 8 scenario 1    4.0     -60.0    0.0    inf    1.0
#           scenario 2    4.0     -60.0    0.0    inf    1.0

# %%
problem1.objective_value
# Out:
# -2200.5
